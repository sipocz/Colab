# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
openfile=open('/content/drive/My Drive/skin/lista.txt')
i=0
pictable=[]
for line in openfile:
    i+=1
    line=line.strip()
    picdata=line.split(",")
    pictable.append(picdata)
    #print(i," ")

# %%
print(pictable[0]) 
print(pictable[1])
# Out:
# ['5436e3abbae478396759f0cf', 'ISIC_0000000']
# ['5436e3acbae478396759f0d1', 'ISIC_0000001']

# %%
import urllib.request
fname0="/content/drive/My Drive/skin/desc/"
i=0
for rec in pictable:
    fname=fname0+rec[0]+".txt"
    txtID=rec[0]
    url="https://isic-archive.com/api/v1/image/"+txtID
    if i % 100 ==0:
        print(i,"..",url,"..",fname)
    urllib.request.urlretrieve(url,fname)
    i=i+1
# Out:
# 0 .. https://isic-archive.com/api/v1/image/5436e3abbae478396759f0cf .. /content/drive/My Drive/skin/desc/5436e3abbae478396759f0cf.txt
# 100 .. https://isic-archive.com/api/v1/image/5436e3b9bae478396759f199 .. /content/drive/My Drive/skin/desc/5436e3b9bae478396759f199.txt
# 200 .. https://isic-archive.com/api/v1/image/5436e3c8bae478396759f261 .. /content/drive/My Drive/skin/desc/5436e3c8bae478396759f261.txt
# 300 .. https://isic-archive.com/api/v1/image/5436e3d1bae478396759f329 .. /content/drive/My Drive/skin/desc/5436e3d1bae478396759f329.txt
# 400 .. https://isic-archive.com/api/v1/image/5436e3dfbae478396759f3f1 .. /content/drive/My Drive/skin/desc/5436e3dfbae478396759f3f1.txt
# 500 .. https://isic-archive.com/api/v1/image/5436e3f5bae478396759f4bc .. /content/drive/My Drive/skin/desc/5436e3f5bae478396759f4bc.txt
# 600 .. https://isic-archive.com/api/v1/image/54d90e06bae4780ab00c2f94 .. /content/drive/My Drive/skin/desc/54d90e06bae4780ab00c2f94.txt
# 700 .. https://isic-archive.com/api/v1/image/54d90e2dbae4780ab00c3188 .. /content/drive/My Drive/skin/desc/54d90e2dbae4780ab00c3188.txt
# 800 .. https://isic-archive.com/api/v1/image/54d90e55bae4780ab00c337c .. /content/drive/My Drive/skin/desc/54d90e55bae4780ab00c337c.txt
# 900 .. https://isic-archive.com/api/v1/image/54d90e78bae4780ab00c3570 .. /content/drive/My Drive/skin/desc/54d90e78bae4780ab00c3570.txt
# 1000 .. https://isic-archive.com/api/v1/image/54d90e9bbae4780ab00c3764 .. /content/drive/My Drive/skin/desc/54d90e9bbae4780ab00c3764.txt
# 1100 .. https://isic-archive.com/api/v1/image/54e755f3bae47850e86cdfc7 .. /content/drive/My Drive/skin/desc/54e755f3bae47850e86cdfc7.txt
# 1200 .. https://isic-archive.com/api/v1/image/54e77f81bae478166c01e60e .. /content/drive/My Drive/skin/desc/54e77f81bae478166c01e60e.txt
# 1300 .. https://isic-archive.com/api/v1/image/54e77fb0bae478166c01e802 .. /content/drive/My Drive/skin/desc/54e77fb0bae478166c01e802.txt
# 1400 .. https://isic-archive.com/api/v1/image/54e77fdabae478166c01e9f6 .. /content/drive/My Drive/skin/desc/54e77fdabae478166c01e9f6.txt
# 1500 .. https://isic-archive.com/api/v1/image/54e7d637bae4780ec59ca98c .. /content/drive/My Drive/skin/desc/54e7d637bae4780ec59ca98c.txt
# 1600 .. https://isic-archive.com/api/v1/image/54e7d65dbae4780ec59cab80 .. /content/drive/My Drive/skin/desc/54e7d65dbae4780ec59cab80.txt
# 1700 .. https://isic-archive.com/api/v1/image/54e7d67ebae4780ec59cad74 .. /content/drive/My Drive/skin/desc/54e7d67ebae4780ec59cad74.txt
# 1800 .. https://isic-archive.com/api/v1/image/54e7d6abbae4780ec59caf68 .. /content/drive/My Drive/skin/desc/54e7d6abbae4780ec59caf68.txt
# 1900 .. https://isic-archive.com/api/v1/image/54e7d6ecbae4780ec59cb15c .. /content/drive/My Drive/skin/desc/54e7d6ecbae4780ec59cb15c.txt
# 2000 .. https://isic-archive.com/api/v1/image/54e7d72abae4780ec59cb350 .. /content/drive/My Drive/skin/desc/54e7d72abae4780ec59cb350.txt
# 2100 .. https://isic-archive.com/api/v1/image/54e7d76dbae4780ec59cb544 .. /content/drive/My Drive/skin/desc/54e7d76dbae4780ec59cb544.txt
# 2200 .. https://isic-archive.com/api/v1/image/54e7d7b6bae4780ec59cb738 .. /content/drive/My Drive/skin/desc/54e7d7b6bae4780ec59cb738.txt
# 2300 .. https://isic-archive.com/api/v1/image/54e7d7fabae4780ec59cb92c .. /content/drive/My Drive/skin/desc/54e7d7fabae4780ec59cb92c.txt
# 2400 .. https://isic-archive.com/api/v1/image/54e7d83ebae4780ec59cbb20 .. /content/drive/My Drive/skin/desc/54e7d83ebae4780ec59cbb20.txt
# 2500 .. https://isic-archive.com/api/v1/image/54e7d883bae4780ec59cbd1a .. /content/drive/My Drive/skin/desc/54e7d883bae4780ec59cbd1a.txt
# 2600 .. https://isic-archive.com/api/v1/image/54e7d8d7bae4780ec59cbf0e .. /content/drive/My Drive/skin/desc/54e7d8d7bae4780ec59cbf0e.txt
# 2700 .. https://isic-archive.com/api/v1/image/54e7d935bae4780ec59cc102 .. /content/drive/My Drive/skin/desc/54e7d935bae4780ec59cc102.txt
# 2800 .. https://isic-archive.com/api/v1/image/54e7d98ebae4780ec59cc2f6 .. /content/drive/My Drive/skin/desc/54e7d98ebae4780ec59cc2f6.txt
# 2900 .. https://isic-archive.com/api/v1/image/54e7d9f3bae4780ec59cc4ea .. /content/drive/My Drive/skin/desc/54e7d9f3bae4780ec59cc4ea.txt
# 3000 .. https://isic-archive.com/api/v1/image/54e7da53bae4780ec59cc6de .. /content/drive/My Drive/skin/desc/54e7da53bae4780ec59cc6de.txt
# 3100 .. https://isic-archive.com/api/v1/image/54e7dab4bae4780ec59cc8d2 .. /content/drive/My Drive/skin/desc/54e7dab4bae4780ec59cc8d2.txt
# 3200 .. https://isic-archive.com/api/v1/image/54e7daf1bae4780ec59ccac6 .. /content/drive/My Drive/skin/desc/54e7daf1bae4780ec59ccac6.txt
# 3300 .. https://isic-archive.com/api/v1/image/54e7db33bae4780ec59cccba .. /content/drive/My Drive/skin/desc/54e7db33bae4780ec59cccba.txt
# 3400 .. https://isic-archive.com/api/v1/image/54e7db7cbae4780ec59cceae .. /content/drive/My Drive/skin/desc/54e7db7cbae4780ec59cceae.txt
# 3500 .. https://isic-archive.com/api/v1/image/54e7dbbebae4780ec59cd0a2 .. /content/drive/My Drive/skin/desc/54e7dbbebae4780ec59cd0a2.txt
# 3600 .. https://isic-archive.com/api/v1/image/54e7dc0abae4780ec59cd296 .. /content/drive/My Drive/skin/desc/54e7dc0abae4780ec59cd296.txt
# 3700 .. https://isic-archive.com/api/v1/image/54e7dc4cbae4780ec59cd48a .. /content/drive/My Drive/skin/desc/54e7dc4cbae4780ec59cd48a.txt
# 3800 .. https://isic-archive.com/api/v1/image/54e7dc90bae4780ec59cd67e .. /content/drive/My Drive/skin/desc/54e7dc90bae4780ec59cd67e.txt
# 3900 .. https://isic-archive.com/api/v1/image/54e7dcd2bae4780ec59cd874 .. /content/drive/My Drive/skin/desc/54e7dcd2bae4780ec59cd874.txt
# 4000 .. https://isic-archive.com/api/v1/image/54e7dd16bae4780ec59cda68 .. /content/drive/My Drive/skin/desc/54e7dd16bae4780ec59cda68.txt
# 4100 .. https://isic-archive.com/api/v1/image/54e7dd5fbae4780ec59cdc5c .. /content/drive/My Drive/skin/desc/54e7dd5fbae4780ec59cdc5c.txt
# 4200 .. https://isic-archive.com/api/v1/image/54e7ddb9bae4780ec59cde50 .. /content/drive/My Drive/skin/desc/54e7ddb9bae4780ec59cde50.txt
# 4300 .. https://isic-archive.com/api/v1/image/54e7de06bae4780ec59ce044 .. /content/drive/My Drive/skin/desc/54e7de06bae4780ec59ce044.txt
# 4400 .. https://isic-archive.com/api/v1/image/54e7de51bae4780ec59ce238 .. /content/drive/My Drive/skin/desc/54e7de51bae4780ec59ce238.txt
# 4500 .. https://isic-archive.com/api/v1/image/54e7de92bae4780ec59ce42c .. /content/drive/My Drive/skin/desc/54e7de92bae4780ec59ce42c.txt
# 4600 .. https://isic-archive.com/api/v1/image/54e7ded6bae4780ec59ce620 .. /content/drive/My Drive/skin/desc/54e7ded6bae4780ec59ce620.txt
# 4700 .. https://isic-archive.com/api/v1/image/54e7df19bae4780ec59ce814 .. /content/drive/My Drive/skin/desc/54e7df19bae4780ec59ce814.txt
# 4800 .. https://isic-archive.com/api/v1/image/54e7df60bae4780ec59cea08 .. /content/drive/My Drive/skin/desc/54e7df60bae4780ec59cea08.txt
# 4900 .. https://isic-archive.com/api/v1/image/54e7dfa2bae4780ec59cebfc .. /content/drive/My Drive/skin/desc/54e7dfa2bae4780ec59cebfc.txt
# 5000 .. https://isic-archive.com/api/v1/image/54e7dff1bae4780ec59cedf0 .. /content/drive/My Drive/skin/desc/54e7dff1bae4780ec59cedf0.txt
# 5100 .. https://isic-archive.com/api/v1/image/54e7e041bae4780ec59cefe5 .. /content/drive/My Drive/skin/desc/54e7e041bae4780ec59cefe5.txt
# 5200 .. https://isic-archive.com/api/v1/image/54e7e083bae4780ec59cf1d9 .. /content/drive/My Drive/skin/desc/54e7e083bae4780ec59cf1d9.txt
# 5300 .. https://isic-archive.com/api/v1/image/54e7e0c3bae4780ec59cf3cd .. /content/drive/My Drive/skin/desc/54e7e0c3bae4780ec59cf3cd.txt
# 5400 .. https://isic-archive.com/api/v1/image/54e7e104bae4780ec59cf5c1 .. /content/drive/My Drive/skin/desc/54e7e104bae4780ec59cf5c1.txt
# 5500 .. https://isic-archive.com/api/v1/image/54e7e156bae4780ec59cf7b5 .. /content/drive/My Drive/skin/desc/54e7e156bae4780ec59cf7b5.txt
# 5600 .. https://isic-archive.com/api/v1/image/54e7e192bae4780ec59cf9a9 .. /content/drive/My Drive/skin/desc/54e7e192bae4780ec59cf9a9.txt
# 5700 .. https://isic-archive.com/api/v1/image/54e7e1c5bae4780ec59cfb9d .. /content/drive/My Drive/skin/desc/54e7e1c5bae4780ec59cfb9d.txt
# 5800 .. https://isic-archive.com/api/v1/image/54e7e1f4bae4780ec59cfd91 .. /content/drive/My Drive/skin/desc/54e7e1f4bae4780ec59cfd91.txt
# 5900 .. https://isic-archive.com/api/v1/image/54e7e226bae4780ec59cff85 .. /content/drive/My Drive/skin/desc/54e7e226bae4780ec59cff85.txt
# 6000 .. https://isic-archive.com/api/v1/image/54e7e257bae4780ec59d0179 .. /content/drive/My Drive/skin/desc/54e7e257bae4780ec59d0179.txt
# 6100 .. https://isic-archive.com/api/v1/image/54e7e28abae4780ec59d036d .. /content/drive/My Drive/skin/desc/54e7e28abae4780ec59d036d.txt
# 6200 .. https://isic-archive.com/api/v1/image/54e7e2babae4780ec59d0561 .. /content/drive/My Drive/skin/desc/54e7e2babae4780ec59d0561.txt
# 6300 .. https://isic-archive.com/api/v1/image/54e7e2ebbae4780ec59d0755 .. /content/drive/My Drive/skin/desc/54e7e2ebbae4780ec59d0755.txt
# 6400 .. https://isic-archive.com/api/v1/image/54e7e31bbae4780ec59d0949 .. /content/drive/My Drive/skin/desc/54e7e31bbae4780ec59d0949.txt
# 6500 .. https://isic-archive.com/api/v1/image/5508fe1abae47817cee4c95e .. /content/drive/My Drive/skin/desc/5508fe1abae47817cee4c95e.txt
# 6600 .. https://isic-archive.com/api/v1/image/5508fe46bae47817cee4cb52 .. /content/drive/My Drive/skin/desc/5508fe46bae47817cee4cb52.txt
# 6700 .. https://isic-archive.com/api/v1/image/5508fe73bae47817cee4cd46 .. /content/drive/My Drive/skin/desc/5508fe73bae47817cee4cd46.txt
# 6800 .. https://isic-archive.com/api/v1/image/5508fe9cbae47817cee4cf3a .. /content/drive/My Drive/skin/desc/5508fe9cbae47817cee4cf3a.txt
# 6900 .. https://isic-archive.com/api/v1/image/5508fec9bae47817cee4d12e .. /content/drive/My Drive/skin/desc/5508fec9bae47817cee4d12e.txt
# 7000 .. https://isic-archive.com/api/v1/image/5508fef4bae47817cee4d322 .. /content/drive/My Drive/skin/desc/5508fef4bae47817cee4d322.txt
# 7100 .. https://isic-archive.com/api/v1/image/5508ff1ebae47817cee4d516 .. /content/drive/My Drive/skin/desc/5508ff1ebae47817cee4d516.txt
# 7200 .. https://isic-archive.com/api/v1/image/5508ff4cbae47817cee4d70a .. /content/drive/My Drive/skin/desc/5508ff4cbae47817cee4d70a.txt
# 7300 .. https://isic-archive.com/api/v1/image/5508ff75bae47817cee4d8fe .. /content/drive/My Drive/skin/desc/5508ff75bae47817cee4d8fe.txt
# 7400 .. https://isic-archive.com/api/v1/image/5508ff9ebae47817cee4daf2 .. /content/drive/My Drive/skin/desc/5508ff9ebae47817cee4daf2.txt
# 7500 .. https://isic-archive.com/api/v1/image/5508ffc7bae47817cee4dce6 .. /content/drive/My Drive/skin/desc/5508ffc7bae47817cee4dce6.txt
# 7600 .. https://isic-archive.com/api/v1/image/5508fff7bae47817cee4deda .. /content/drive/My Drive/skin/desc/5508fff7bae47817cee4deda.txt
# 7700 .. https://isic-archive.com/api/v1/image/55090022bae47817cee4e0ce .. /content/drive/My Drive/skin/desc/55090022bae47817cee4e0ce.txt
# 7800 .. https://isic-archive.com/api/v1/image/55090051bae47817cee4e2c2 .. /content/drive/My Drive/skin/desc/55090051bae47817cee4e2c2.txt
# 7900 .. https://isic-archive.com/api/v1/image/5509007cbae47817cee4e4b6 .. /content/drive/My Drive/skin/desc/5509007cbae47817cee4e4b6.txt
# 8000 .. https://isic-archive.com/api/v1/image/550900a6bae47817cee4e6aa .. /content/drive/My Drive/skin/desc/550900a6bae47817cee4e6aa.txt
# 8100 .. https://isic-archive.com/api/v1/image/550900d4bae47817cee4e89e .. /content/drive/My Drive/skin/desc/550900d4bae47817cee4e89e.txt
# 8200 .. https://isic-archive.com/api/v1/image/5509023abae478359aa58120 .. /content/drive/My Drive/skin/desc/5509023abae478359aa58120.txt
# 8300 .. https://isic-archive.com/api/v1/image/55090268bae478359aa58314 .. /content/drive/My Drive/skin/desc/55090268bae478359aa58314.txt
# 8400 .. https://isic-archive.com/api/v1/image/55090295bae478359aa58508 .. /content/drive/My Drive/skin/desc/55090295bae478359aa58508.txt
# 8500 .. https://isic-archive.com/api/v1/image/550902c5bae478359aa586fc .. /content/drive/My Drive/skin/desc/550902c5bae478359aa586fc.txt
# 8600 .. https://isic-archive.com/api/v1/image/550902f4bae478359aa588f5 .. /content/drive/My Drive/skin/desc/550902f4bae478359aa588f5.txt
# 8700 .. https://isic-archive.com/api/v1/image/55090327bae478359aa58ae9 .. /content/drive/My Drive/skin/desc/55090327bae478359aa58ae9.txt
# 8800 .. https://isic-archive.com/api/v1/image/55090353bae478359aa58cdd .. /content/drive/My Drive/skin/desc/55090353bae478359aa58cdd.txt
# 8900 .. https://isic-archive.com/api/v1/image/55090384bae478359aa58ed1 .. /content/drive/My Drive/skin/desc/55090384bae478359aa58ed1.txt
# 9000 .. https://isic-archive.com/api/v1/image/550903b2bae478359aa590c5 .. /content/drive/My Drive/skin/desc/550903b2bae478359aa590c5.txt
# 9100 .. https://isic-archive.com/api/v1/image/550903e2bae478359aa592b9 .. /content/drive/My Drive/skin/desc/550903e2bae478359aa592b9.txt
# 9200 .. https://isic-archive.com/api/v1/image/5509040fbae478359aa594b2 .. /content/drive/My Drive/skin/desc/5509040fbae478359aa594b2.txt
# 9300 .. https://isic-archive.com/api/v1/image/55090443bae478359aa596a6 .. /content/drive/My Drive/skin/desc/55090443bae478359aa596a6.txt
# 9400 .. https://isic-archive.com/api/v1/image/55090471bae478359aa5989a .. /content/drive/My Drive/skin/desc/55090471bae478359aa5989a.txt
# 9500 .. https://isic-archive.com/api/v1/image/550904a6bae478359aa59a8e .. /content/drive/My Drive/skin/desc/550904a6bae478359aa59a8e.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-837748dec6f9> in <module>()
#       8     if i % 100 ==0:
#       9         print(i,"..",url,"..",fname)
# ---> 10     urllib.request.urlretrieve(url,fname)
#      11     i=i+1
#      12
#
# /usr/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
