# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/Colab/blob/main/gpos_lin/_earthquake_distance_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
_PCVERSION_=False


if _PCVERSION_:
    basedir="C:/Users/sipocz/OneDrive/Dokumentumok/GitHub"
else:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    basedir="/content/drive/My Drive/001_AI/_EarthQuake/gpos_lin"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#--------------scikit import 
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

#--------------
def outlierStatistic(X_train_predict):
    print(X_train_predict)
    maxX=len(X_train_predict)
    outlier=0
    for i in X_train_predict:
        if i==-1:
            outlier+=1
    print(f"A összes ({maxX} darabból {outlier} darab outlier van. Az {outlier/maxX*100:5.1f} %.)")


def checkvalues(df,columnname,key):
    print(f"{columnname} ellenőrzése !")
    numok=0
    numerr=0
    for i in df.index:
        if df.at[i,columnname] in key:
            #print(df.at[i,columnname])
            numok+=1
            pass
        else:
            numerr+=1
            print(df.at[i,columnname],end=", ")
    sumall=numok+numerr
    print(f"\n{sumall} mintából {numerr} db nem volt megfelelő")


def createcolumn(df,columnname,keys):
    print(f"{columnname} cseréje megy")
    for key in keys:
        df[keys[key]]=0.0
    for key in keys:
        for i in df.index:
            if df.at[i,columnname]==key:
                df.at[i,keys[key]]=1.0


def create_dict(idx,list):
    o={}
    for i in list:
        o[i]=idx+"_"+i
    return o

def create_base_data(df):
    t=['n', 't', 'o']
    columnname="land_surface_condition"
    key=create_dict(columnname,t)


    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t= ['h', 'w', 'i', 'r', 'u']
    columnname="foundation_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=  ['q', 'n', 'x']
    columnname="roof_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=  ['z', 'v', 'f', 'm', 'x']
    columnname="ground_floor_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['q', 's', 'j', 'x']
    columnname="other_floor_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['j', 's', 't', 'o']
    columnname="position"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['c', 's', 'f', 'd', 'm', 'a', 'q', 'u', 'n', 'o']
    columnname="plan_configuration"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=['a', 'w', 'r', 'v']
    columnname="legal_ownership_status"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    # level 1: 0-30, level 2: 0-1427, level 3: 0-12567.
    # level1:0--30
    # level2: 0.0000-----------0.9999
    # level3: 0.000000000------0.000099999
    l1=df.geo_level_1_id
    l2=(df.geo_level_2_id/1427*9999)/10000
    l3=(df.geo_level_2_id/12567*99999)/1000000000
    df["geopos"]=l1+l2+l3
    return(df)



def kill_columns(df):
    notkey=["Unnamed: 0","building_id","legal_ownership_status","geo_level_1_id",	"geo_level_2_id",	"geo_level_3_id", "land_surface_condition",	"foundation_type",	"roof_type",	"ground_floor_type",	"other_floor_type",	"position",	"plan_configuration"]
    for i in df.columns:
        print(i)
        if i in notkey:
            df.drop(columns=[i], inplace=True)
    return df
# Out:
# Mounted at /content/drive

# %%
features_train=basedir+"/orig/train_values.csv"
labels_train=basedir+"/orig/train_labels.csv"
features_predict=basedir+"/orig/test_values.csv"

X_train=pd.read_csv(features_train)
y_train=pd.read_csv(labels_train)
X_pred=pd.read_csv(features_predict)
#
X_pred_conv=create_base_data(X_pred)
X_train_conv=create_base_data(X_train)
#
X_train_ok=kill_columns(X_train_conv)
X_pred_ok=kill_columns(X_pred_conv)
y_train_ok=kill_columns(y_train)

X_train_ok.to_csv(basedir+"/tmp/X_tran_ok.csv",index=False)
X_pred_ok.to_csv(basedir+"/tmp/X_pred_ok.csv",index=False)
y_train_ok.to_csv(basedir+"/tmp/y_train_ok.csv",index=False)




#f=open(basedir+"/tmp/similarity.csv","a")
X_train_ok=pd.read_csv(basedir+"/tmp/X_tran_ok.csv",)
X_pred_ok=pd.read_csv(basedir+"/tmp/X_pred_ok.csv")
y_train_ok=pd.read_csv(basedir+"/tmp/y_train_ok.csv")

X_train_ok.head()
X_pred_ok.head()
print("Ready")
# Out:
# land_surface_condition cseréje megy
# foundation_type cseréje megy
# roof_type cseréje megy
# ground_floor_type cseréje megy
# other_floor_type cseréje megy
# position cseréje megy
# plan_configuration cseréje megy
# legal_ownership_status cseréje megy
# land_surface_condition cseréje megy
# foundation_type cseréje megy
# roof_type cseréje megy
# ground_floor_type cseréje megy
# other_floor_type cseréje megy
# position cseréje megy
# plan_configuration cseréje megy
# legal_ownership_status cseréje megy
# building_id
# geo_level_1_id
# geo_level_2_id
# geo_level_3_id
# count_floors_pre_eq
# age
# area_percentage
# height_percentage
# land_surface_condition
# foundation_type
# roof_type
# ground_floor_type
# other_floor_type
# position
# plan_configuration
# has_superstructure_adobe_mud
# has_superstructure_mud_mortar_stone
# has_superstructure_stone_flag
# has_superstructure_cement_mortar_stone
# has_superstructure_mud_mortar_brick
# has_superstructure_cement_mortar_brick
# has_superstructure_timber
# has_superstructure_bamboo
# has_superstructure_rc_non_engineered
# has_superstructure_rc_engineered
# has_superstructure_other
# legal_ownership_status
# count_families
# has_secondary_use
# has_secondary_use_agriculture
# has_secondary_use_hotel
# has_secondary_use_rental
# has_secondary_use_institution
# has_secondary_use_school
# has_secondary_use_industry
# has_secondary_use_health_post
# has_secondary_use_gov_office
# has_secondary_use_use_police
# has_secondary_use_other
# land_surface_condition_n
# land_surface_condition_t
# land_surface_condition_o
# foundation_type_h
# foundation_type_w
# foundation_type_i
# foundation_type_r
# foundation_type_u
# roof_type_q
# roof_type_n
# roof_type_x
# ground_floor_type_z
# ground_floor_type_v
# ground_floor_type_f
# ground_floor_type_m
# ground_floor_type_x
# other_floor_type_q
# other_floor_type_s
# other_floor_type_j
# other_floor_type_x
# position_j
# position_s
# position_t
# position_o
# plan_configuration_c
# plan_configuration_s
# plan_configuration_f
# plan_configuration_d
# plan_configuration_m
# plan_configuration_a
# plan_configuration_q
# plan_configuration_u
# plan_configuration_n
# plan_configuration_o
# legal_ownership_status_a
# legal_ownership_status_w
# legal_ownership_status_r
# legal_ownership_status_v
# geopos
# building_id
# geo_level_1_id
# geo_level_2_id
# geo_level_3_id
# count_floors_pre_eq
# age
# area_percentage
# height_percentage
# land_surface_condition
# foundation_type
# roof_type
# ground_floor_type
# other_floor_type
# position
# plan_configuration
# has_superstructure_adobe_mud
# has_superstructure_mud_mortar_stone
# has_superstructure_stone_flag
# has_superstructure_cement_mortar_stone
# has_superstructure_mud_mortar_brick
# has_superstructure_cement_mortar_brick
# has_superstructure_timber
# has_superstructure_bamboo
# has_superstructure_rc_non_engineered
# has_superstructure_rc_engineered
# has_superstructure_other
# legal_ownership_status
# count_families
# has_secondary_use
# has_secondary_use_agriculture
# has_secondary_use_hotel
# has_secondary_use_rental
# has_secondary_use_institution
# has_secondary_use_school
# has_secondary_use_industry
# has_secondary_use_health_post
# has_secondary_use_gov_office
# has_secondary_use_use_police
# has_secondary_use_other
# land_surface_condition_n
# land_surface_condition_t
# land_surface_condition_o
# foundation_type_h
# foundation_type_w
# foundation_type_i
# foundation_type_r
# foundation_type_u
# roof_type_q
# roof_type_n
# roof_type_x
# ground_floor_type_z
# ground_floor_type_v
# ground_floor_type_f
# ground_floor_type_m
# ground_floor_type_x
# other_floor_type_q
# other_floor_type_s
# other_floor_type_j
# other_floor_type_x
# position_j
# position_s
# position_t
# position_o
# plan_configuration_c
# plan_configuration_s
# plan_configuration_f
# plan_configuration_d
# plan_configuration_m
# plan_configuration_a
# plan_configuration_q
# plan_configuration_u
# plan_configuration_n
# plan_configuration_o
# legal_ownership_status_a
# legal_ownership_status_w
# legal_ownership_status_r
# legal_ownership_status_v
# geopos
# building_id
# damage_grade
# Ready

# %%
from xgboost import XGBClassifier  # 72.09
# max_depth=10 : 72.79857561664441

knn = XGBClassifier(verbosity=3,max_depth = 30)

print("Fit: Inlier betanitás Start--")
knn.fit(X_train_ok, y_train_ok)
print("Fit End - Prediction Start ")
# Out:
# [11:49:17] ======== Monitor: Learner ========
# [11:49:17] GetGradient: 3.32258s, 100 calls @ 33225us
# [11:49:17] PredictRaw: 0.277985s, 100 calls @ 2779us
# [11:49:17] UpdateOneIter: 416.614s, 100 calls @ 4166141us
# [11:49:17] ======== Monitor: GBTree ========
# [11:49:17] BoostNewTrees: 386.062s, 100 calls @ 3860622us
# [11:49:17] CommitModel: 26.9502s, 100 calls @ 269501us
# Fit: Inlier betanitás Start--
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [11:49:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18754 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51476 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48806 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19464 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53806 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50594 extra nodes, 0 pruned nodes, max_depth=30
# [11:49:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19920 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55868 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51792 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20548 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 57622 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52774 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21196 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59564 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53336 extra nodes, 0 pruned nodes, max_depth=30
# [11:50:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21392 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60272 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54324 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22108 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61546 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55154 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22410 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62588 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55838 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22624 extra nodes, 0 pruned nodes, max_depth=30
# [11:51:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64242 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55276 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23132 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64518 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55864 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23512 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64750 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54934 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23730 extra nodes, 0 pruned nodes, max_depth=30
# [11:52:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66366 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54804 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23736 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66050 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53852 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23902 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66724 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53932 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24224 extra nodes, 0 pruned nodes, max_depth=30
# [11:53:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66292 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52512 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24150 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 65292 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51952 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24228 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64618 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52466 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23382 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64198 extra nodes, 0 pruned nodes, max_depth=30
# [11:54:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52298 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23702 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60128 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51968 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23190 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59316 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50440 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23160 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59182 extra nodes, 0 pruned nodes, max_depth=30
# [11:55:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 49356 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23136 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58222 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 49054 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23088 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58110 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 47602 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22776 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53922 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46680 extra nodes, 0 pruned nodes, max_depth=30
# [11:56:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22756 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48990 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 45388 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22520 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 45854 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44830 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22326 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 43960 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 43618 extra nodes, 0 pruned nodes, max_depth=30
# [11:57:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21622 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42530 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 43030 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21470 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39732 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40692 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21154 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39796 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39808 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20658 extra nodes, 0 pruned nodes, max_depth=30
# [11:58:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39206 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37652 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20326 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37164 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36710 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20864 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37806 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37088 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20854 extra nodes, 0 pruned nodes, max_depth=30
# [11:59:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36610 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 35306 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20230 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 35418 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33600 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19526 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34372 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33430 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18830 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33586 extra nodes, 0 pruned nodes, max_depth=30
# [12:00:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33460 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18352 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 31800 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30094 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18348 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30898 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28812 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17874 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30632 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26576 extra nodes, 0 pruned nodes, max_depth=30
# [12:01:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17576 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28000 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26050 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17616 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:22] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 27690 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 25104 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17464 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 25294 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24178 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16230 extra nodes, 0 pruned nodes, max_depth=30
# [12:02:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24980 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24836 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16326 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 25376 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:22] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24592 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16744 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21246 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22538 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16544 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20380 extra nodes, 0 pruned nodes, max_depth=30
# [12:03:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21764 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16916 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17368 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23008 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16636 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18990 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21058 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16290 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20930 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21772 extra nodes, 0 pruned nodes, max_depth=30
# [12:04:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16420 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20828 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19878 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15852 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20354 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20746 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16588 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18324 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20310 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15932 extra nodes, 0 pruned nodes, max_depth=30
# [12:05:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19926 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18542 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16234 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19864 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19236 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15244 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19932 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19620 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14206 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18346 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17864 extra nodes, 0 pruned nodes, max_depth=30
# [12:06:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14456 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19038 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17916 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14042 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18466 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15276 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14500 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16602 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18476 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13798 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17078 extra nodes, 0 pruned nodes, max_depth=30
# [12:07:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14722 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13508 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13334 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12628 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13224 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16014 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12924 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13102 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12264 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12474 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13160 extra nodes, 0 pruned nodes, max_depth=30
# [12:08:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14292 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10678 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13090 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13856 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9328 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12928 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12658 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12942 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12716 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16074 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10344 extra nodes, 0 pruned nodes, max_depth=30
# [12:09:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13318 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15740 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10370 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12514 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12772 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8928 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12334 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19500 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10470 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12658 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11082 extra nodes, 0 pruned nodes, max_depth=30
# [12:10:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8214 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12452 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12754 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8076 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12318 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13502 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8690 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11686 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10806 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9092 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11940 extra nodes, 0 pruned nodes, max_depth=30
# [12:11:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11064 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11182 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11744 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13098 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8278 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11574 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12880 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8498 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10826 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9826 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6312 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10850 extra nodes, 0 pruned nodes, max_depth=30
# [12:12:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12286 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7140 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11400 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10632 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8900 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11542 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11668 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6422 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10482 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9942 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7146 extra nodes, 0 pruned nodes, max_depth=30
# [12:13:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10726 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9872 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8872 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11410 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9322 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6666 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10254 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8806 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8052 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9538 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8816 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14294 extra nodes, 0 pruned nodes, max_depth=30
# [12:14:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9640 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8204 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8914 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9576 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7008 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10112 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9336 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7256 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9894 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9486 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7474 extra nodes, 0 pruned nodes, max_depth=30
# [12:15:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7848 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9594 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5904 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6946 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9712 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7744 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6648 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9600 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10154 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9942 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9110 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6466 extra nodes, 0 pruned nodes, max_depth=30
# [12:16:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6526 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7916 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8888 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6798 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8746 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7890 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7512 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8534 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6336 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9994 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8530 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5364 extra nodes, 0 pruned nodes, max_depth=30
# [12:17:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6418 extra nodes, 0 pruned nodes, max_depth=30
# [12:18:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8932 extra nodes, 0 pruned nodes, max_depth=30
# [12:18:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4286 extra nodes, 0 pruned nodes, max_depth=30
# [12:18:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9696 extra nodes, 0 pruned nodes, max_depth=30
# Fit End - Prediction Start

# %%
y_pred=knn.predict(X_train_ok)
print("Prediction End")

accuracy =  accuracy_score(y_pred, y_train_ok) * 100
print(f"Accuracy a betanított halmazra : {accuracy}")
# Out:
# Prediction End
# Accuracy a betanított halmazra : 95.87607108184542

# %%
X_pred_ok=kill_columns(X_pred_ok)
# Out:
# count_floors_pre_eq
# age
# area_percentage
# height_percentage
# has_superstructure_adobe_mud
# has_superstructure_mud_mortar_stone
# has_superstructure_stone_flag
# has_superstructure_cement_mortar_stone
# has_superstructure_mud_mortar_brick
# has_superstructure_cement_mortar_brick
# has_superstructure_timber
# has_superstructure_bamboo
# has_superstructure_rc_non_engineered
# has_superstructure_rc_engineered
# has_superstructure_other
# count_families
# has_secondary_use
# has_secondary_use_agriculture
# has_secondary_use_hotel
# has_secondary_use_rental
# has_secondary_use_institution
# has_secondary_use_school
# has_secondary_use_industry
# has_secondary_use_health_post
# has_secondary_use_gov_office
# has_secondary_use_use_police
# has_secondary_use_other
# land_surface_condition_n
# land_surface_condition_t
# land_surface_condition_o
# foundation_type_h
# foundation_type_w
# foundation_type_i
# foundation_type_r
# foundation_type_u
# roof_type_q
# roof_type_n
# roof_type_x
# ground_floor_type_z
# ground_floor_type_v
# ground_floor_type_f
# ground_floor_type_m
# ground_floor_type_x
# other_floor_type_q
# other_floor_type_s
# other_floor_type_j
# other_floor_type_x
# position_j
# position_s
# position_t
# position_o
# plan_configuration_c
# plan_configuration_s
# plan_configuration_f
# plan_configuration_d
# plan_configuration_m
# plan_configuration_a
# plan_configuration_q
# plan_configuration_u
# plan_configuration_n
# plan_configuration_o
# legal_ownership_status_a
# legal_ownership_status_w
# legal_ownership_status_r
# legal_ownership_status_v
# geopos

# %%
#outfile generation
y_pred_ok=knn.predict(X_pred_ok)
print("Prediction End")

X_pred_bd=pd.read_csv(basedir+"/orig/test_values.csv")
# Out:
# Prediction End

# %%
X_pred_bd
# Out:
#        building_id  ...  has_secondary_use_other
# 0           300051  ...                        0
# 1            99355  ...                        0
# 2           890251  ...                        0
# 3           745817  ...                        0
# 4           421793  ...                        0
# ...            ...  ...                      ...
# 86863       310028  ...                        0
# 86864       663567  ...                        0
# 86865      1049160  ...                        0
# 86866       442785  ...                        0
# 86867       501372  ...                        0
#
# [86868 rows x 39 columns]

# %%
buildingid=X_pred_bd["building_id"]
head2=y_pred_ok


outdf=pd.DataFrame(data={"damage_grade":y_pred_ok} ,index=buildingid)
outdf.index.name="building_id"


outdf.head()


outdf.to_csv(basedir+"/out/submission_20_xgboost.csv")
print()
print(basedir+"/out/submission_20_xgboost.csv")
# Out:
# /content/drive/My Drive/001_AI/_EarthQuake/gpos_lin/out/submission_20_xgboost.csv

# %%
if not( _PCVERSION_):
    # !head "/content/drive/My Drive/001_AI/_EarthQuake/gpos_lin/out/submission_20_xgboost.csv"
# Out:
# building_id,damage_grade
# 300051,3
# 99355,3
# 890251,2
# 745817,2
# 421793,3
# 871976,2
# 691228,1
# 896100,3
# 343471,2
