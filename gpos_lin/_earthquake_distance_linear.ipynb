# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/Colab/blob/main/gpos_lin/_earthquake_distance_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
_PCVERSION_=False


if _PCVERSION_:
    basedir="C:/Users/sipocz/OneDrive/Dokumentumok/GitHub"
else:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    basedir="/content/drive/My Drive/001_AI/_EarthQuake/gpos_lin"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#--------------scikit import 
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
#--------------

def outlierStatistic(X_train_predict):
    print(X_train_predict)
    maxX=len(X_train_predict)
    outlier=0
    for i in X_train_predict:
        if i==-1:
            outlier+=1
    print(f"A összes ({maxX} darabból {outlier} darab outlier van. Az {outlier/maxX*100:5.1f} %.)")


def checkvalues(df,columnname,key):
    print(f"{columnname} ellenőrzése !")
    numok=0
    numerr=0
    for i in df.index:
        if df.at[i,columnname] in key:
            #print(df.at[i,columnname])
            numok+=1
            pass
        else:
            numerr+=1
            print(df.at[i,columnname],end=", ")
    sumall=numok+numerr
    print(f"\n{sumall} mintából {numerr} db nem volt megfelelő")


def createcolumn(df,columnname,keys):
    print(f"{columnname} cseréje megy")
    for key in keys:
        df[keys[key]]=0.0
    for key in keys:
        for i in df.index:
            if df.at[i,columnname]==key:
                df.at[i,keys[key]]=1.0


def create_dict(idx,list):
    o={}
    for i in list:
        o[i]=idx+"_"+i
    return o

def create_base_data(df):
    t=['n', 't', 'o']
    columnname="land_surface_condition"
    key=create_dict(columnname,t)


    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t= ['h', 'w', 'i', 'r', 'u']
    columnname="foundation_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=  ['q', 'n', 'x']
    columnname="roof_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=  ['z', 'v', 'f', 'm', 'x']
    columnname="ground_floor_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['q', 's', 'j', 'x']
    columnname="other_floor_type"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['j', 's', 't', 'o']
    columnname="position"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=   ['c', 's', 'f', 'd', 'm', 'a', 'q', 'u', 'n', 'o']
    columnname="plan_configuration"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    t=['a', 'w', 'r', 'v']
    columnname="legal_ownership_status"
    key=create_dict(columnname,t)

    #checkvalues(df,columnname,key)
    createcolumn(df,columnname,key)

    # level 1: 0-30, level 2: 0-1427, level 3: 0-12567.
    # level1:0--30
    # level2: 0.0000-----------0.9999
    # level3: 0.000000000------0.000099999
    l1=df.geo_level_1_id
    l2=(df.geo_level_2_id/1427*9999)/10000
    l3=(df.geo_level_2_id/12567*99999)/1000000000
    df["geopos"]=l1+l2+l3
    return(df)



def kill_columns(df):
    notkey=["Unnamed: 0","building_id","legal_ownership_status","geo_level_1_id",	"geo_level_2_id",	"geo_level_3_id", "land_surface_condition",	"foundation_type",	"roof_type",	"ground_floor_type",	"other_floor_type",	"position",	"plan_configuration"]
    for i in df.columns:
        #print(i)
        if i in notkey:
            df.drop(columns=[i], inplace=True)
    return df
# Out:
# Mounted at /content/drive

# %%
features_train=basedir+"/orig/train_values.csv"
labels_train=basedir+"/orig/train_labels.csv"
features_predict=basedir+"/orig/test_values.csv"

X_train=pd.read_csv(features_train)
y_train=pd.read_csv(labels_train)
X_pred=pd.read_csv(features_predict)
#
X_pred_conv=create_base_data(X_pred)
X_train_conv=create_base_data(X_train)
#
X_train_ok=kill_columns(X_train_conv)
X_pred_ok=kill_columns(X_pred_conv)
y_train_ok=kill_columns(y_train)

X_train_ok.to_csv(basedir+"/tmp/X_tran_ok.csv",index=False)
X_pred_ok.to_csv(basedir+"/tmp/X_pred_ok.csv",index=False)
y_train_ok.to_csv(basedir+"/tmp/y_train_ok.csv",index=False)




#f=open(basedir+"/tmp/similarity.csv","a")
X_train_ok=pd.read_csv(basedir+"/tmp/X_tran_ok.csv",)
X_pred_ok=pd.read_csv(basedir+"/tmp/X_pred_ok.csv")
y_train_ok=pd.read_csv(basedir+"/tmp/y_train_ok.csv")

X_train_ok.head()
X_pred_ok.head()
#print("Ready")
# Out:
# land_surface_condition cseréje megy
# foundation_type cseréje megy
# roof_type cseréje megy
# ground_floor_type cseréje megy
# other_floor_type cseréje megy
# position cseréje megy
# plan_configuration cseréje megy
# legal_ownership_status cseréje megy
# land_surface_condition cseréje megy
# foundation_type cseréje megy
# roof_type cseréje megy
# ground_floor_type cseréje megy
# other_floor_type cseréje megy
# position cseréje megy
# plan_configuration cseréje megy
# legal_ownership_status cseréje megy
#    count_floors_pre_eq  age  ...  legal_ownership_status_v     geopos
# 0                    3   20  ...                       1.0  17.417622
# 1                    2   25  ...                       1.0   6.098800
# 2                    2    5  ...                       1.0  22.013313
# 3                    1    0  ...                       1.0  26.027328
# 4                    3   15  ...                       1.0  17.202505
#
# [5 rows x 66 columns]

# %%
X_pred_ok=kill_columns(X_pred_ok)
X_train_ok=kill_columns(X_train_ok)
y_train_ok=kill_columns(y_train_ok)

# %%
from sklearn.preprocessing import StandardScaler

scaler1=StandardScaler()
X_pred_scale=scaler1.fit_transform(X_pred_ok)

scaler2=StandardScaler()
X_train_scale=scaler2.fit_transform(X_train_ok)

scaler3=StandardScaler()
y_train_scale=scaler3.fit_transform(y_train_ok)


# szétszedjük a train és test részekre
from sklearn.model_selection import train_test_split
X_train_train, X_train_test,y_train_train, y_train_test  = train_test_split( X_train_scale, y_train_scale, test_size=0.10, random_state=0)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=45)
pca.fit(X_train_train)
X_train_train_pca_principal=pca.transform(X_train_train)
X_train_test_pca_principal=pca.transform(X_train_test)

# %%
from xgboost import XGBClassifier  # 72.09
# max_depth=10 : 72.79857561664441

knn = XGBClassifier(verbosity=3,max_depth = 90,n_estimators=250)

print("Fit: Inlier betanitás Start--")
knn.fit(X_train_train_pca_principal, y_train_train)
print("Fit End - Prediction Start ")
# Out:
# Fit: Inlier betanitás Start--
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [17:05:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18018 extra nodes, 0 pruned nodes, max_depth=41
# [17:06:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58018 extra nodes, 0 pruned nodes, max_depth=54
# [17:06:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 49888 extra nodes, 0 pruned nodes, max_depth=45
# [17:06:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18360 extra nodes, 0 pruned nodes, max_depth=44
# [17:06:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58826 extra nodes, 0 pruned nodes, max_depth=47
# [17:07:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50558 extra nodes, 0 pruned nodes, max_depth=50
# [17:07:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18458 extra nodes, 0 pruned nodes, max_depth=45
# [17:07:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59192 extra nodes, 0 pruned nodes, max_depth=63
# [17:07:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50790 extra nodes, 0 pruned nodes, max_depth=47
# [17:07:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18908 extra nodes, 0 pruned nodes, max_depth=43
# [17:08:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59668 extra nodes, 0 pruned nodes, max_depth=58
# [17:08:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50532 extra nodes, 0 pruned nodes, max_depth=51
# [17:08:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19038 extra nodes, 0 pruned nodes, max_depth=42
# [17:09:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60024 extra nodes, 0 pruned nodes, max_depth=55
# [17:09:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51284 extra nodes, 0 pruned nodes, max_depth=47
# [17:09:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19400 extra nodes, 0 pruned nodes, max_depth=47
# [17:09:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60772 extra nodes, 0 pruned nodes, max_depth=59
# [17:10:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51652 extra nodes, 0 pruned nodes, max_depth=46
# [17:10:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19322 extra nodes, 0 pruned nodes, max_depth=50
# [17:10:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60848 extra nodes, 0 pruned nodes, max_depth=68
# [17:10:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51672 extra nodes, 0 pruned nodes, max_depth=56
# [17:11:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19484 extra nodes, 0 pruned nodes, max_depth=45
# [17:11:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61066 extra nodes, 0 pruned nodes, max_depth=64
# [17:11:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51982 extra nodes, 0 pruned nodes, max_depth=49
# [17:11:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19520 extra nodes, 0 pruned nodes, max_depth=39
# [17:12:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61608 extra nodes, 0 pruned nodes, max_depth=56
# [17:12:22] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51672 extra nodes, 0 pruned nodes, max_depth=50
# [17:12:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19518 extra nodes, 0 pruned nodes, max_depth=40
# [17:12:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61912 extra nodes, 0 pruned nodes, max_depth=73
# [17:13:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51966 extra nodes, 0 pruned nodes, max_depth=55
# [17:13:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19888 extra nodes, 0 pruned nodes, max_depth=42
# [17:13:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61804 extra nodes, 0 pruned nodes, max_depth=74
# [17:14:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51814 extra nodes, 0 pruned nodes, max_depth=61
# [17:14:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19752 extra nodes, 0 pruned nodes, max_depth=59
# [17:14:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61850 extra nodes, 0 pruned nodes, max_depth=72
# [17:14:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51864 extra nodes, 0 pruned nodes, max_depth=51
# [17:15:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19630 extra nodes, 0 pruned nodes, max_depth=39
# [17:15:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62082 extra nodes, 0 pruned nodes, max_depth=88
# [17:15:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51560 extra nodes, 0 pruned nodes, max_depth=50
# [17:15:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19808 extra nodes, 0 pruned nodes, max_depth=42
# [17:16:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61800 extra nodes, 0 pruned nodes, max_depth=71
# [17:16:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51306 extra nodes, 0 pruned nodes, max_depth=63
# [17:16:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19694 extra nodes, 0 pruned nodes, max_depth=46
# [17:17:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 61180 extra nodes, 0 pruned nodes, max_depth=61
# [17:17:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50688 extra nodes, 0 pruned nodes, max_depth=67
# [17:17:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19508 extra nodes, 0 pruned nodes, max_depth=49
# [17:17:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60364 extra nodes, 0 pruned nodes, max_depth=87
# [17:18:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50156 extra nodes, 0 pruned nodes, max_depth=61
# [17:18:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19256 extra nodes, 0 pruned nodes, max_depth=43
# [17:18:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 59582 extra nodes, 0 pruned nodes, max_depth=70
# [17:19:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 49628 extra nodes, 0 pruned nodes, max_depth=57
# [17:19:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 19000 extra nodes, 0 pruned nodes, max_depth=54
# [17:19:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58644 extra nodes, 0 pruned nodes, max_depth=62
# [17:19:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48972 extra nodes, 0 pruned nodes, max_depth=69
# [17:20:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18788 extra nodes, 0 pruned nodes, max_depth=48
# [17:20:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 57604 extra nodes, 0 pruned nodes, max_depth=79
# [17:20:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48196 extra nodes, 0 pruned nodes, max_depth=51
# [17:20:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18800 extra nodes, 0 pruned nodes, max_depth=51
# [17:21:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56680 extra nodes, 0 pruned nodes, max_depth=80
# [17:21:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 47680 extra nodes, 0 pruned nodes, max_depth=63
# [17:21:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18600 extra nodes, 0 pruned nodes, max_depth=60
# [17:22:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 55930 extra nodes, 0 pruned nodes, max_depth=90
# [17:22:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46188 extra nodes, 0 pruned nodes, max_depth=67
# [17:22:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18126 extra nodes, 0 pruned nodes, max_depth=53
# [17:23:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54736 extra nodes, 0 pruned nodes, max_depth=90
# [17:23:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 45904 extra nodes, 0 pruned nodes, max_depth=60
# [17:23:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18040 extra nodes, 0 pruned nodes, max_depth=54
# [17:24:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53734 extra nodes, 0 pruned nodes, max_depth=77
# [17:24:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 45320 extra nodes, 0 pruned nodes, max_depth=65
# [17:24:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17506 extra nodes, 0 pruned nodes, max_depth=48
# [17:24:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 53148 extra nodes, 0 pruned nodes, max_depth=73
# [17:25:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44146 extra nodes, 0 pruned nodes, max_depth=74
# [17:25:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17336 extra nodes, 0 pruned nodes, max_depth=48
# [17:25:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 51940 extra nodes, 0 pruned nodes, max_depth=77
# [17:26:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 43520 extra nodes, 0 pruned nodes, max_depth=63
# [17:26:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17044 extra nodes, 0 pruned nodes, max_depth=49
# [17:26:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50940 extra nodes, 0 pruned nodes, max_depth=86
# [17:27:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42986 extra nodes, 0 pruned nodes, max_depth=67
# [17:27:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16900 extra nodes, 0 pruned nodes, max_depth=45
# [17:27:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50210 extra nodes, 0 pruned nodes, max_depth=78
# [17:28:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 41854 extra nodes, 0 pruned nodes, max_depth=76
# [17:28:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16512 extra nodes, 0 pruned nodes, max_depth=56
# [17:28:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 49368 extra nodes, 0 pruned nodes, max_depth=90
# [17:29:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 41068 extra nodes, 0 pruned nodes, max_depth=71
# [17:29:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16240 extra nodes, 0 pruned nodes, max_depth=48
# [17:29:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48436 extra nodes, 0 pruned nodes, max_depth=90
# [17:29:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40350 extra nodes, 0 pruned nodes, max_depth=57
# [17:30:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15976 extra nodes, 0 pruned nodes, max_depth=52
# [17:30:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 47374 extra nodes, 0 pruned nodes, max_depth=89
# [17:30:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39522 extra nodes, 0 pruned nodes, max_depth=76
# [17:31:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15780 extra nodes, 0 pruned nodes, max_depth=56
# [17:31:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46544 extra nodes, 0 pruned nodes, max_depth=85
# [17:31:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38916 extra nodes, 0 pruned nodes, max_depth=86
# [17:32:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15556 extra nodes, 0 pruned nodes, max_depth=57
# [17:32:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 45692 extra nodes, 0 pruned nodes, max_depth=90
# [17:32:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38186 extra nodes, 0 pruned nodes, max_depth=87
# [17:33:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15332 extra nodes, 0 pruned nodes, max_depth=57
# [17:33:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44806 extra nodes, 0 pruned nodes, max_depth=90
# [17:33:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37556 extra nodes, 0 pruned nodes, max_depth=82
# [17:34:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15006 extra nodes, 0 pruned nodes, max_depth=75
# [17:34:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44080 extra nodes, 0 pruned nodes, max_depth=90
# [17:35:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36610 extra nodes, 0 pruned nodes, max_depth=77
# [17:35:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14800 extra nodes, 0 pruned nodes, max_depth=62
# [17:35:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 43154 extra nodes, 0 pruned nodes, max_depth=90
# [17:36:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 35814 extra nodes, 0 pruned nodes, max_depth=78
# [17:36:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14506 extra nodes, 0 pruned nodes, max_depth=56
# [17:36:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42104 extra nodes, 0 pruned nodes, max_depth=90
# [17:37:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 35166 extra nodes, 0 pruned nodes, max_depth=90
# [17:37:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14242 extra nodes, 0 pruned nodes, max_depth=54
# [17:37:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40542 extra nodes, 0 pruned nodes, max_depth=90
# [17:38:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34810 extra nodes, 0 pruned nodes, max_depth=89
# [17:38:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14018 extra nodes, 0 pruned nodes, max_depth=59
# [17:38:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40594 extra nodes, 0 pruned nodes, max_depth=90
# [17:39:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33548 extra nodes, 0 pruned nodes, max_depth=90
# [17:39:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13926 extra nodes, 0 pruned nodes, max_depth=63
# [17:40:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 39002 extra nodes, 0 pruned nodes, max_depth=90
# [17:40:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33370 extra nodes, 0 pruned nodes, max_depth=90
# [17:40:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13582 extra nodes, 0 pruned nodes, max_depth=64
# [17:41:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38014 extra nodes, 0 pruned nodes, max_depth=90
# [17:41:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32478 extra nodes, 0 pruned nodes, max_depth=90
# [17:41:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13310 extra nodes, 0 pruned nodes, max_depth=80
# [17:42:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38448 extra nodes, 0 pruned nodes, max_depth=90
# [17:42:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 31794 extra nodes, 0 pruned nodes, max_depth=90
# [17:42:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13070 extra nodes, 0 pruned nodes, max_depth=70
# [17:43:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 37474 extra nodes, 0 pruned nodes, max_depth=90
# [17:43:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 31614 extra nodes, 0 pruned nodes, max_depth=90
# [17:44:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12902 extra nodes, 0 pruned nodes, max_depth=72
# [17:44:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34846 extra nodes, 0 pruned nodes, max_depth=90
# [17:44:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 29808 extra nodes, 0 pruned nodes, max_depth=90
# [17:45:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12598 extra nodes, 0 pruned nodes, max_depth=82
# [17:45:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34420 extra nodes, 0 pruned nodes, max_depth=90
# [17:46:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30158 extra nodes, 0 pruned nodes, max_depth=90
# [17:46:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12422 extra nodes, 0 pruned nodes, max_depth=68
# [17:46:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34062 extra nodes, 0 pruned nodes, max_depth=90
# [17:47:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 29008 extra nodes, 0 pruned nodes, max_depth=90
# [17:47:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12184 extra nodes, 0 pruned nodes, max_depth=59
# [17:48:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 33646 extra nodes, 0 pruned nodes, max_depth=90
# [17:48:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 29008 extra nodes, 0 pruned nodes, max_depth=90
# [17:48:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12032 extra nodes, 0 pruned nodes, max_depth=71
# [17:49:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32142 extra nodes, 0 pruned nodes, max_depth=90
# [17:49:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28970 extra nodes, 0 pruned nodes, max_depth=90
# [17:49:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11724 extra nodes, 0 pruned nodes, max_depth=77
# [17:50:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32096 extra nodes, 0 pruned nodes, max_depth=90
# [17:50:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28260 extra nodes, 0 pruned nodes, max_depth=90
# [17:51:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11552 extra nodes, 0 pruned nodes, max_depth=80
# [17:51:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 31418 extra nodes, 0 pruned nodes, max_depth=90
# [17:52:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 27376 extra nodes, 0 pruned nodes, max_depth=90
# [17:52:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11410 extra nodes, 0 pruned nodes, max_depth=83
# [17:52:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 29538 extra nodes, 0 pruned nodes, max_depth=90
# [17:53:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 27202 extra nodes, 0 pruned nodes, max_depth=90
# [17:53:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11252 extra nodes, 0 pruned nodes, max_depth=78
# [17:54:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28732 extra nodes, 0 pruned nodes, max_depth=90
# [17:54:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26720 extra nodes, 0 pruned nodes, max_depth=90
# [17:54:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11064 extra nodes, 0 pruned nodes, max_depth=85
# [17:55:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23742 extra nodes, 0 pruned nodes, max_depth=90
# [17:55:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 25466 extra nodes, 0 pruned nodes, max_depth=90
# [17:56:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10876 extra nodes, 0 pruned nodes, max_depth=89
# [17:56:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 27722 extra nodes, 0 pruned nodes, max_depth=90
# [17:57:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24992 extra nodes, 0 pruned nodes, max_depth=90
# [17:57:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10688 extra nodes, 0 pruned nodes, max_depth=85
# [17:57:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28812 extra nodes, 0 pruned nodes, max_depth=90
# [17:58:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24578 extra nodes, 0 pruned nodes, max_depth=90
# [17:58:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10424 extra nodes, 0 pruned nodes, max_depth=90
# [17:59:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26150 extra nodes, 0 pruned nodes, max_depth=90
# [17:59:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24348 extra nodes, 0 pruned nodes, max_depth=90
# [17:59:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10458 extra nodes, 0 pruned nodes, max_depth=75
# [18:00:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23940 extra nodes, 0 pruned nodes, max_depth=90
# [18:00:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23196 extra nodes, 0 pruned nodes, max_depth=90
# [18:01:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10110 extra nodes, 0 pruned nodes, max_depth=90
# [18:01:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22488 extra nodes, 0 pruned nodes, max_depth=90
# [18:02:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22360 extra nodes, 0 pruned nodes, max_depth=90
# [18:02:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9914 extra nodes, 0 pruned nodes, max_depth=89
# [18:03:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22190 extra nodes, 0 pruned nodes, max_depth=90
# [18:03:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 23476 extra nodes, 0 pruned nodes, max_depth=90
# [18:03:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9966 extra nodes, 0 pruned nodes, max_depth=69
# [18:04:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21788 extra nodes, 0 pruned nodes, max_depth=90
# [18:04:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21292 extra nodes, 0 pruned nodes, max_depth=90
# [18:05:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9804 extra nodes, 0 pruned nodes, max_depth=87
# [18:05:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20490 extra nodes, 0 pruned nodes, max_depth=90
# [18:06:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21462 extra nodes, 0 pruned nodes, max_depth=90
# [18:06:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9514 extra nodes, 0 pruned nodes, max_depth=90
# [18:07:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18052 extra nodes, 0 pruned nodes, max_depth=90
# [18:07:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21754 extra nodes, 0 pruned nodes, max_depth=90
# [18:07:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9382 extra nodes, 0 pruned nodes, max_depth=90
# [18:08:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17302 extra nodes, 0 pruned nodes, max_depth=90
# [18:08:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 21192 extra nodes, 0 pruned nodes, max_depth=90
# [18:09:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9072 extra nodes, 0 pruned nodes, max_depth=90
# [18:09:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15750 extra nodes, 0 pruned nodes, max_depth=90
# [18:10:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20198 extra nodes, 0 pruned nodes, max_depth=90
# [18:10:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9304 extra nodes, 0 pruned nodes, max_depth=90
# [18:10:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14014 extra nodes, 0 pruned nodes, max_depth=90
# [18:11:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22982 extra nodes, 0 pruned nodes, max_depth=90
# [18:11:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9204 extra nodes, 0 pruned nodes, max_depth=85
# [18:12:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16612 extra nodes, 0 pruned nodes, max_depth=90
# [18:12:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22398 extra nodes, 0 pruned nodes, max_depth=90
# [18:13:00] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9072 extra nodes, 0 pruned nodes, max_depth=88
# [18:13:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17354 extra nodes, 0 pruned nodes, max_depth=90
# [18:14:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22086 extra nodes, 0 pruned nodes, max_depth=90
# [18:14:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8834 extra nodes, 0 pruned nodes, max_depth=90
# [18:14:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15106 extra nodes, 0 pruned nodes, max_depth=90
# [18:15:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18134 extra nodes, 0 pruned nodes, max_depth=90
# [18:15:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8854 extra nodes, 0 pruned nodes, max_depth=82
# [18:16:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12768 extra nodes, 0 pruned nodes, max_depth=90
# [18:16:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20468 extra nodes, 0 pruned nodes, max_depth=90
# [18:16:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8472 extra nodes, 0 pruned nodes, max_depth=90
# [18:17:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14180 extra nodes, 0 pruned nodes, max_depth=90
# [18:17:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20076 extra nodes, 0 pruned nodes, max_depth=90
# [18:18:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8624 extra nodes, 0 pruned nodes, max_depth=80
# [18:18:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15782 extra nodes, 0 pruned nodes, max_depth=90
# [18:19:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15778 extra nodes, 0 pruned nodes, max_depth=90
# [18:19:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8310 extra nodes, 0 pruned nodes, max_depth=90
# [18:20:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14304 extra nodes, 0 pruned nodes, max_depth=90
# [18:20:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18464 extra nodes, 0 pruned nodes, max_depth=90
# [18:20:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8238 extra nodes, 0 pruned nodes, max_depth=90
# [18:21:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10760 extra nodes, 0 pruned nodes, max_depth=90
# [18:21:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18000 extra nodes, 0 pruned nodes, max_depth=90
# [18:22:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8350 extra nodes, 0 pruned nodes, max_depth=90
# [18:22:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13282 extra nodes, 0 pruned nodes, max_depth=90
# [18:23:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17982 extra nodes, 0 pruned nodes, max_depth=90
# [18:23:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8110 extra nodes, 0 pruned nodes, max_depth=90
# [18:24:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12048 extra nodes, 0 pruned nodes, max_depth=90
# [18:24:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15310 extra nodes, 0 pruned nodes, max_depth=90
# [18:24:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8058 extra nodes, 0 pruned nodes, max_depth=90
# [18:25:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11900 extra nodes, 0 pruned nodes, max_depth=90
# [18:25:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15792 extra nodes, 0 pruned nodes, max_depth=90
# [18:26:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8046 extra nodes, 0 pruned nodes, max_depth=90
# [18:26:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10508 extra nodes, 0 pruned nodes, max_depth=90
# [18:27:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15278 extra nodes, 0 pruned nodes, max_depth=90
# [18:27:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7580 extra nodes, 0 pruned nodes, max_depth=90
# [18:28:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11164 extra nodes, 0 pruned nodes, max_depth=90
# [18:28:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13170 extra nodes, 0 pruned nodes, max_depth=90
# [18:28:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7612 extra nodes, 0 pruned nodes, max_depth=90
# [18:29:22] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12310 extra nodes, 0 pruned nodes, max_depth=90
# [18:29:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17396 extra nodes, 0 pruned nodes, max_depth=90
# [18:30:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7742 extra nodes, 0 pruned nodes, max_depth=90
# [18:30:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16058 extra nodes, 0 pruned nodes, max_depth=90
# [18:31:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12538 extra nodes, 0 pruned nodes, max_depth=90
# [18:31:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7672 extra nodes, 0 pruned nodes, max_depth=90
# [18:32:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14716 extra nodes, 0 pruned nodes, max_depth=90
# [18:32:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 17608 extra nodes, 0 pruned nodes, max_depth=90
# [18:32:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7566 extra nodes, 0 pruned nodes, max_depth=90
# [18:33:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10410 extra nodes, 0 pruned nodes, max_depth=90
# [18:33:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15702 extra nodes, 0 pruned nodes, max_depth=90
# [18:34:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7266 extra nodes, 0 pruned nodes, max_depth=90
# [18:34:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11464 extra nodes, 0 pruned nodes, max_depth=90
# [18:35:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14970 extra nodes, 0 pruned nodes, max_depth=90
# [18:35:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7270 extra nodes, 0 pruned nodes, max_depth=90
# [18:35:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10798 extra nodes, 0 pruned nodes, max_depth=90
# [18:36:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11380 extra nodes, 0 pruned nodes, max_depth=90
# [18:36:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7448 extra nodes, 0 pruned nodes, max_depth=90
# [18:37:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10636 extra nodes, 0 pruned nodes, max_depth=90
# [18:37:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13538 extra nodes, 0 pruned nodes, max_depth=90
# [18:38:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7134 extra nodes, 0 pruned nodes, max_depth=90
# [18:38:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9150 extra nodes, 0 pruned nodes, max_depth=90
# [18:39:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12382 extra nodes, 0 pruned nodes, max_depth=90
# [18:39:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7074 extra nodes, 0 pruned nodes, max_depth=90
# [18:39:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7746 extra nodes, 0 pruned nodes, max_depth=90
# [18:40:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10398 extra nodes, 0 pruned nodes, max_depth=90
# [18:40:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7060 extra nodes, 0 pruned nodes, max_depth=90
# [18:41:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9138 extra nodes, 0 pruned nodes, max_depth=90
# [18:41:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13456 extra nodes, 0 pruned nodes, max_depth=90
# [18:42:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6948 extra nodes, 0 pruned nodes, max_depth=90
# [18:42:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7570 extra nodes, 0 pruned nodes, max_depth=90
# [18:42:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6902 extra nodes, 0 pruned nodes, max_depth=90
# [18:43:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7172 extra nodes, 0 pruned nodes, max_depth=87
# [18:43:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8230 extra nodes, 0 pruned nodes, max_depth=90
# [18:44:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 15056 extra nodes, 0 pruned nodes, max_depth=90
# [18:44:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6820 extra nodes, 0 pruned nodes, max_depth=90
# [18:45:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6176 extra nodes, 0 pruned nodes, max_depth=90
# [18:45:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10394 extra nodes, 0 pruned nodes, max_depth=90
# [18:45:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6838 extra nodes, 0 pruned nodes, max_depth=90
# [18:46:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8754 extra nodes, 0 pruned nodes, max_depth=90
# [18:46:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 13070 extra nodes, 0 pruned nodes, max_depth=90
# [18:47:11] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6806 extra nodes, 0 pruned nodes, max_depth=90
# [18:47:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7996 extra nodes, 0 pruned nodes, max_depth=90
# [18:48:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7158 extra nodes, 0 pruned nodes, max_depth=90
# [18:48:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6880 extra nodes, 0 pruned nodes, max_depth=90
# [18:48:57] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6008 extra nodes, 0 pruned nodes, max_depth=90
# [18:49:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9210 extra nodes, 0 pruned nodes, max_depth=90
# [18:49:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6758 extra nodes, 0 pruned nodes, max_depth=90
# [18:50:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5256 extra nodes, 0 pruned nodes, max_depth=90
# [18:50:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11774 extra nodes, 0 pruned nodes, max_depth=90
# [18:51:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6654 extra nodes, 0 pruned nodes, max_depth=90
# [18:51:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8392 extra nodes, 0 pruned nodes, max_depth=90
# [18:52:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8080 extra nodes, 0 pruned nodes, max_depth=90
# [18:52:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6504 extra nodes, 0 pruned nodes, max_depth=90
# [18:52:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6950 extra nodes, 0 pruned nodes, max_depth=90
# [18:53:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8474 extra nodes, 0 pruned nodes, max_depth=90
# [18:53:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6436 extra nodes, 0 pruned nodes, max_depth=90
# [18:54:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5904 extra nodes, 0 pruned nodes, max_depth=90
# [18:54:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8272 extra nodes, 0 pruned nodes, max_depth=90
# [18:54:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6726 extra nodes, 0 pruned nodes, max_depth=71
# [18:55:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5460 extra nodes, 0 pruned nodes, max_depth=90
# [18:55:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11556 extra nodes, 0 pruned nodes, max_depth=90
# [18:56:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6436 extra nodes, 0 pruned nodes, max_depth=90
# [18:56:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4976 extra nodes, 0 pruned nodes, max_depth=90
# [18:57:01] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5426 extra nodes, 0 pruned nodes, max_depth=90
# [18:57:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6636 extra nodes, 0 pruned nodes, max_depth=87
# [18:57:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5152 extra nodes, 0 pruned nodes, max_depth=90
# [18:58:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4844 extra nodes, 0 pruned nodes, max_depth=90
# [18:58:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6486 extra nodes, 0 pruned nodes, max_depth=90
# [18:59:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5308 extra nodes, 0 pruned nodes, max_depth=90
# [18:59:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8838 extra nodes, 0 pruned nodes, max_depth=90
# [18:59:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6246 extra nodes, 0 pruned nodes, max_depth=90
# [19:00:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3978 extra nodes, 0 pruned nodes, max_depth=90
# [19:00:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12006 extra nodes, 0 pruned nodes, max_depth=90
# [19:01:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6044 extra nodes, 0 pruned nodes, max_depth=90
# [19:01:34] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5166 extra nodes, 0 pruned nodes, max_depth=90
# [19:02:04] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12270 extra nodes, 0 pruned nodes, max_depth=90
# [19:02:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6208 extra nodes, 0 pruned nodes, max_depth=90
# [19:02:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5396 extra nodes, 0 pruned nodes, max_depth=90
# [19:03:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7628 extra nodes, 0 pruned nodes, max_depth=90
# [19:03:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5878 extra nodes, 0 pruned nodes, max_depth=90
# [19:04:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4768 extra nodes, 0 pruned nodes, max_depth=90
# [19:04:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9430 extra nodes, 0 pruned nodes, max_depth=90
# [19:04:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5854 extra nodes, 0 pruned nodes, max_depth=90
# [19:05:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4832 extra nodes, 0 pruned nodes, max_depth=90
# [19:05:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3818 extra nodes, 0 pruned nodes, max_depth=90
# [19:06:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5564 extra nodes, 0 pruned nodes, max_depth=90
# [19:06:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4838 extra nodes, 0 pruned nodes, max_depth=90
# [19:07:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7516 extra nodes, 0 pruned nodes, max_depth=90
# [19:07:27] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6132 extra nodes, 0 pruned nodes, max_depth=90
# [19:07:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5896 extra nodes, 0 pruned nodes, max_depth=90
# [19:08:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6538 extra nodes, 0 pruned nodes, max_depth=90
# [19:08:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5688 extra nodes, 0 pruned nodes, max_depth=90
# [19:09:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6234 extra nodes, 0 pruned nodes, max_depth=90
# [19:09:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4904 extra nodes, 0 pruned nodes, max_depth=90
# [19:09:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5842 extra nodes, 0 pruned nodes, max_depth=90
# [19:10:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4546 extra nodes, 0 pruned nodes, max_depth=90
# [19:10:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4094 extra nodes, 0 pruned nodes, max_depth=90
# [19:11:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6192 extra nodes, 0 pruned nodes, max_depth=76
# [19:11:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6068 extra nodes, 0 pruned nodes, max_depth=90
# [19:12:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9598 extra nodes, 0 pruned nodes, max_depth=90
# [19:12:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5564 extra nodes, 0 pruned nodes, max_depth=90
# [19:12:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3954 extra nodes, 0 pruned nodes, max_depth=90
# [19:13:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6846 extra nodes, 0 pruned nodes, max_depth=90
# [19:13:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6102 extra nodes, 0 pruned nodes, max_depth=90
# [19:14:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3718 extra nodes, 0 pruned nodes, max_depth=90
# [19:14:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4868 extra nodes, 0 pruned nodes, max_depth=90
# [19:14:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6080 extra nodes, 0 pruned nodes, max_depth=88
# [19:15:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4132 extra nodes, 0 pruned nodes, max_depth=90
# [19:15:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4770 extra nodes, 0 pruned nodes, max_depth=90
# [19:16:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5598 extra nodes, 0 pruned nodes, max_depth=90
# [19:16:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2918 extra nodes, 0 pruned nodes, max_depth=90
# [19:16:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4190 extra nodes, 0 pruned nodes, max_depth=90
# [19:17:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5752 extra nodes, 0 pruned nodes, max_depth=90
# [19:17:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3794 extra nodes, 0 pruned nodes, max_depth=90
# [19:18:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8986 extra nodes, 0 pruned nodes, max_depth=90
# [19:18:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5736 extra nodes, 0 pruned nodes, max_depth=90
# [19:19:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3768 extra nodes, 0 pruned nodes, max_depth=90
# [19:19:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3388 extra nodes, 0 pruned nodes, max_depth=90
# [19:19:47] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5828 extra nodes, 0 pruned nodes, max_depth=90
# [19:20:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3928 extra nodes, 0 pruned nodes, max_depth=90
# [19:20:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2894 extra nodes, 0 pruned nodes, max_depth=90
# [19:20:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5864 extra nodes, 0 pruned nodes, max_depth=90
# [19:21:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2716 extra nodes, 0 pruned nodes, max_depth=90
# [19:21:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6888 extra nodes, 0 pruned nodes, max_depth=90
# [19:22:12] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5632 extra nodes, 0 pruned nodes, max_depth=90
# [19:22:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3710 extra nodes, 0 pruned nodes, max_depth=90
# [19:23:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9246 extra nodes, 0 pruned nodes, max_depth=90
# [19:23:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5872 extra nodes, 0 pruned nodes, max_depth=90
# [19:23:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6490 extra nodes, 0 pruned nodes, max_depth=90
# [19:24:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4542 extra nodes, 0 pruned nodes, max_depth=90
# [19:24:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5176 extra nodes, 0 pruned nodes, max_depth=90
# [19:25:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2562 extra nodes, 0 pruned nodes, max_depth=90
# [19:25:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5626 extra nodes, 0 pruned nodes, max_depth=90
# [19:25:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5780 extra nodes, 0 pruned nodes, max_depth=89
# [19:26:22] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3024 extra nodes, 0 pruned nodes, max_depth=90
# [19:26:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10092 extra nodes, 0 pruned nodes, max_depth=90
# [19:27:14] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5612 extra nodes, 0 pruned nodes, max_depth=90
# [19:27:41] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4540 extra nodes, 0 pruned nodes, max_depth=90
# [19:28:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4088 extra nodes, 0 pruned nodes, max_depth=90
# [19:28:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5578 extra nodes, 0 pruned nodes, max_depth=90
# [19:28:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2614 extra nodes, 0 pruned nodes, max_depth=90
# [19:29:19] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4328 extra nodes, 0 pruned nodes, max_depth=90
# [19:29:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5668 extra nodes, 0 pruned nodes, max_depth=84
# [19:30:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2394 extra nodes, 0 pruned nodes, max_depth=90
# [19:30:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4036 extra nodes, 0 pruned nodes, max_depth=90
# [19:30:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5662 extra nodes, 0 pruned nodes, max_depth=87
# [19:31:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2544 extra nodes, 0 pruned nodes, max_depth=90
# [19:31:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7878 extra nodes, 0 pruned nodes, max_depth=90
# [19:32:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5600 extra nodes, 0 pruned nodes, max_depth=90
# [19:32:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1894 extra nodes, 0 pruned nodes, max_depth=90
# [19:32:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3580 extra nodes, 0 pruned nodes, max_depth=90
# [19:33:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5682 extra nodes, 0 pruned nodes, max_depth=83
# [19:33:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2574 extra nodes, 0 pruned nodes, max_depth=90
# [19:34:05] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4776 extra nodes, 0 pruned nodes, max_depth=90
# [19:34:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5610 extra nodes, 0 pruned nodes, max_depth=90
# [19:34:52] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3712 extra nodes, 0 pruned nodes, max_depth=90
# [19:35:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2810 extra nodes, 0 pruned nodes, max_depth=90
# [19:35:38] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5494 extra nodes, 0 pruned nodes, max_depth=90
# [19:36:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2310 extra nodes, 0 pruned nodes, max_depth=90
# [19:36:29] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4160 extra nodes, 0 pruned nodes, max_depth=90
# [19:36:50] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5248 extra nodes, 0 pruned nodes, max_depth=90
# [19:37:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2466 extra nodes, 0 pruned nodes, max_depth=90
# [19:37:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4380 extra nodes, 0 pruned nodes, max_depth=90
# [19:38:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5478 extra nodes, 0 pruned nodes, max_depth=90
# [19:38:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1622 extra nodes, 0 pruned nodes, max_depth=90
# [19:38:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8944 extra nodes, 0 pruned nodes, max_depth=90
# [19:39:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5170 extra nodes, 0 pruned nodes, max_depth=90
# [19:39:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4900 extra nodes, 0 pruned nodes, max_depth=90
# [19:40:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3086 extra nodes, 0 pruned nodes, max_depth=90
# [19:40:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5090 extra nodes, 0 pruned nodes, max_depth=90
# [19:40:54] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1832 extra nodes, 0 pruned nodes, max_depth=90
# [19:41:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10070 extra nodes, 0 pruned nodes, max_depth=90
# [19:41:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4840 extra nodes, 0 pruned nodes, max_depth=90
# [19:42:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2646 extra nodes, 0 pruned nodes, max_depth=90
# [19:42:35] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3200 extra nodes, 0 pruned nodes, max_depth=90
# [19:42:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5438 extra nodes, 0 pruned nodes, max_depth=90
# [19:43:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3254 extra nodes, 0 pruned nodes, max_depth=90
# [19:43:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2274 extra nodes, 0 pruned nodes, max_depth=90
# [19:44:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5094 extra nodes, 0 pruned nodes, max_depth=90
# [19:44:31] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1686 extra nodes, 0 pruned nodes, max_depth=90
# [19:44:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4676 extra nodes, 0 pruned nodes, max_depth=90
# [19:45:18] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5402 extra nodes, 0 pruned nodes, max_depth=90
# [19:45:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3926 extra nodes, 0 pruned nodes, max_depth=90
# [19:46:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2562 extra nodes, 0 pruned nodes, max_depth=90
# [19:46:32] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4748 extra nodes, 0 pruned nodes, max_depth=90
# [19:46:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2582 extra nodes, 0 pruned nodes, max_depth=90
# [19:47:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4438 extra nodes, 0 pruned nodes, max_depth=90
# [19:47:45] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5360 extra nodes, 0 pruned nodes, max_depth=82
# [19:48:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1980 extra nodes, 0 pruned nodes, max_depth=90
# [19:48:36] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3856 extra nodes, 0 pruned nodes, max_depth=90
# [19:48:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5112 extra nodes, 0 pruned nodes, max_depth=90
# [19:49:28] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 9774 extra nodes, 0 pruned nodes, max_depth=90
# [19:49:55] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4082 extra nodes, 0 pruned nodes, max_depth=90
# [19:50:15] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4604 extra nodes, 0 pruned nodes, max_depth=90
# [19:50:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2324 extra nodes, 0 pruned nodes, max_depth=90
# [19:51:07] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3600 extra nodes, 0 pruned nodes, max_depth=90
# [19:51:26] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5288 extra nodes, 0 pruned nodes, max_depth=87
# [19:51:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1786 extra nodes, 0 pruned nodes, max_depth=90
# [19:52:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10066 extra nodes, 0 pruned nodes, max_depth=90
# [19:52:43] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4694 extra nodes, 0 pruned nodes, max_depth=90
# [19:53:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2508 extra nodes, 0 pruned nodes, max_depth=90
# [19:53:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2294 extra nodes, 0 pruned nodes, max_depth=90
# [19:53:53] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4876 extra nodes, 0 pruned nodes, max_depth=90
# [19:54:17] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1764 extra nodes, 0 pruned nodes, max_depth=90
# [19:54:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11780 extra nodes, 0 pruned nodes, max_depth=90
# [19:55:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4354 extra nodes, 0 pruned nodes, max_depth=90
# [19:55:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6198 extra nodes, 0 pruned nodes, max_depth=90
# [19:56:10] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8594 extra nodes, 0 pruned nodes, max_depth=90
# [19:56:30] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5206 extra nodes, 0 pruned nodes, max_depth=86
# [19:56:56] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3176 extra nodes, 0 pruned nodes, max_depth=90
# [19:57:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2514 extra nodes, 0 pruned nodes, max_depth=90
# [19:57:44] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4700 extra nodes, 0 pruned nodes, max_depth=90
# [19:58:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2006 extra nodes, 0 pruned nodes, max_depth=90
# [19:58:39] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12238 extra nodes, 0 pruned nodes, max_depth=90
# [19:58:59] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5026 extra nodes, 0 pruned nodes, max_depth=90
# [19:59:24] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2104 extra nodes, 0 pruned nodes, max_depth=90
# [19:59:51] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4530 extra nodes, 0 pruned nodes, max_depth=90
# [20:00:13] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4652 extra nodes, 0 pruned nodes, max_depth=90
# [20:00:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1468 extra nodes, 0 pruned nodes, max_depth=90
# [20:01:03] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3394 extra nodes, 0 pruned nodes, max_depth=90
# [20:01:25] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4738 extra nodes, 0 pruned nodes, max_depth=90
# [20:01:49] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1754 extra nodes, 0 pruned nodes, max_depth=90
# [20:02:20] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 11890 extra nodes, 0 pruned nodes, max_depth=90
# [20:02:42] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4816 extra nodes, 0 pruned nodes, max_depth=90
# [20:03:06] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1566 extra nodes, 0 pruned nodes, max_depth=90
# [20:03:37] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8738 extra nodes, 0 pruned nodes, max_depth=90
# [20:03:58] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4710 extra nodes, 0 pruned nodes, max_depth=90
# [20:04:23] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2104 extra nodes, 0 pruned nodes, max_depth=90
# [20:04:48] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2728 extra nodes, 0 pruned nodes, max_depth=90
# [20:05:09] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4518 extra nodes, 0 pruned nodes, max_depth=90
# [20:05:33] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1310 extra nodes, 0 pruned nodes, max_depth=90
# [20:06:02] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5464 extra nodes, 0 pruned nodes, max_depth=90
# [20:06:21] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 5104 extra nodes, 0 pruned nodes, max_depth=82
# [20:06:46] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2064 extra nodes, 0 pruned nodes, max_depth=90
# [20:07:16] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 7240 extra nodes, 0 pruned nodes, max_depth=90
# [20:07:40] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4650 extra nodes, 0 pruned nodes, max_depth=90
# [20:08:08] INFO: /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 3910 extra nodes, 0 pruned nodes, max_depth=90

# %%
#test the prediction

y_pred_test=knn.predict(X_train_test_pca_principal)

# %%
y_pred_test_nor_real=scaler3.inverse_transform(y_pred_test)
y_pred_test_nor_int=[]
for i in range(len(y_pred_test_nor_real)):
    y_pred_test_nor_int.append(int(y_pred_test_nor_real[i]))


y_train_test_nor_real=scaler3.inverse_transform(y_train_test)
y_train_test_nor_int=[]
for i in range(len(y_train_test_nor_real)):
    y_train_test_nor_int.append(int(y_train_test_nor_real[i]))

# %%
db=0
maxi=0
for ind, i in enumerate(y_train_test_nor_int):
    maxi+=1
    i2=y_pred_test_nor_int[ind]
    if i!=i2:
        db+=1
    #print(f"{ind}. eset:  {i:3},{i2:3}")
print(f"hiba:{db} max:{maxi} -- %:{db/maxi*100.0 : 6} ")
# Out:
# hiba:8897 max:26061 -- %: 34.139135106097235

# %%
#outfile generation
X_pred_pca_principal=pca.transform(X_pred_scale)
y_pred_ok=knn.predict(X_pred_pca_principal)
print("Prediction End")

y_pred_ok=scaler3.inverse_transform(y_pred_ok)
X_pred_bd=pd.read_csv(basedir+"/orig/test_values.csv")

y_pred_ok_int=[]
for i in range(len(y_pred_ok)):
    y_pred_ok_int.append(int(y_pred_ok[i]))
# Out:
# Prediction End

# %%
buildingid=X_pred_bd["building_id"]
head2=y_pred_ok_int


outdf=pd.DataFrame(data={"damage_grade":y_pred_ok_int} ,index=buildingid)
outdf.index.name="building_id"


outdf.head()


outdf.to_csv(basedir+"/out/submission_23_xgboost.csv")
print()
print(basedir+"/out/submission_23_xgboost.csv")
# Out:
# /content/drive/My Drive/001_AI/_EarthQuake/gpos_lin/out/submission_23_xgboost.csv

# %%
if not( _PCVERSION_):
    # !head "/content/drive/My Drive/001_AI/_EarthQuake/gpos_lin/out/submission_23_xgboost.csv"
# Out:
# building_id,damage_grade
# 300051,3
# 99355,2
# 890251,2
# 745817,2
# 421793,3
# 871976,3
# 691228,2
# 896100,3
# 343471,2
